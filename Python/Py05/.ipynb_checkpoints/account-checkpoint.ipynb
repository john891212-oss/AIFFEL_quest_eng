# %%
    a.account() 계좌생성 메서드 (은행명, 계좌주, 계좌번호)
    만든 계좌수 정보 메서드
    deposit 입금 메서드
    withdraw 출금 메서드
    정보 출력 메서드 잔고 계좌 번호 예금주 은행
    이자 지급
    여러 객체 생성 3개 이상 리스트에 저장기능 append()
    객체 순회 
    입금 출금 내역 조회 기능 업데이

# %%
import random

class Account():
    self.account_made_num = 0
    
    def __init__(self): ##계좌 정보 초기값및 양식 저장         
        self.bank_name = "SC은행"
        self.account_name = "홍길동"
        self.acoount_num = "111-11-111111"
        self.account_pound = "0"
        
class Bank_made_account(Account): ##계좌생성메서드 이름과 잔액을 넣어 인스턴스 생성 + 계좌번호 + 계좌생성횟수 기록
        def __init__(self, name, pound):
            super().__init__()
            self.account_name = name
            self.account_pound = pound
    
    
            
            i = random.randint(1,999)
            d = random.randint(1,99)
            e = random.randint(1,999999)
    
            self.account_num = f"{i}-{d}-{e}"
            print("계좌가 생성되었습니다.")
            
            self.deposit_history = []
            self.withdraw_history = []
            
            Account.account_made_num += 1
            print(f"은행이름:{self.bank_name}계좌번호:{self.account_num} 예금주 이름:{self.account_name} 잔액:{self.account_pound}")

        def get_account_num(self):
            print(f"SC은행 총계좌수 :{Account.account_made_num}")

        def deposit(self):
            depo = 0
            while not (1 <= depo):
                try:
                    depo = int(input("입금액을 입력해주세요 1원이상만 가능:")
                    if 1 <= depo:
                        self.account_pound_sum = self.account_pound + depo
                        print(f"{depo}원 입금성공")
                    else:
                        print("입금실패")
                        depo = 0
                except ValueError:
                    print("금액을 입력해주세요.")
                    depo = 0
            
            self.deposit_history.append(depo)


        def withdraw(self):
            print("잔액은 {self.account_pound_sum}입니다.")
            if self.account_pound_sum =< 0:
                print("잔액이 부족해 인출이 불가능합니다.")
                ### 기능 선택 메뉴로 이동
            else:
                wi = 0 
                while not wi = 0
                    try:
                        wi = int(input("출금액수를 적어주세요:")
                        if wi > self.account_pound_sum:
                            print("잔액이 모자랍니다.")
                        else:
                            print(f"{wi}원이 출력됩니다.")
                            self.account_pound_sum = self.account_pound_sum - wi
                    except ValueError:
                        print("숫자를 입력해주세요.")
                        wi = 0
                
            self.withdraw_history.append(wi)
        
        def display_info(self):
            formatted = f"{num:,}"  # "1,234,567,890"
            print(f"은행이름:{self.bank_name}계좌번호:{self.account_num} 예금주 이름:{self.account_name} 잔액:{self.account_pround_sum:,}")
            print("입금 내역")
            for om in range(len(self.deposit_history)):
                print("  ",om+1,self.deposit_history[om])
                print(f"잔고 : {self.account_pound_sum:,}")
            print("출금 내역")
            for om in range(len(self.with_history)):
                print("  ",om+1,self.withdraw_history[om])
                print(f"잔고 : {self.account_pound_sum:,}")
                
        def bank_run(self):
            print("은행업무를 도와드리겠습니다.")
            choice = 0
            while choice not in [1,2,3]
                try:
                    int(input("1번 입금 2번 출금 3번 계좌정보 조회 입니다."))
                    if choice == 1:
                        self.deposit()
                    elif choice == 2:
                        self.withdraw()
                    elif choice == 3:
                        self.display_info()
                    elif choice == 4:
                        print("이용해주셔서 감사합니다.")
                        break
                    else:
                        print("1~4 중에서 선택해주세요.")
                except ValueError:
                    print("숫자를 입력해주세요.")
# Out:
#   Cell In[2], line 41
#     if 1 <= depo:
#                 ^
# SyntaxError: invalid syntax

# %%
a =  Account()
b = Bank_made_account(Account)
