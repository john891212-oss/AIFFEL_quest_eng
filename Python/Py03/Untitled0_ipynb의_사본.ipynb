# %% [markdown]
# <a href="https://colab.research.google.com/github/john891212-oss/AIFFEL_quest_eng/blob/main/Python/Py03/Untitled0_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 계산기 만들기 input (x,y) (+,-,/,*,**) 기능이 있어야 합니다
# 정수가 아니면 value에러
# 다시 입력하기 나와야 합니다.
# 나누셈 연산시 0이면 zero에 나와야합니다.
# 연사자를 잘못 입력하면 적절한 오류메시지가 나와야합니다.
# math 모듈써서 ** 처리
# 계산기를 통해 계산 계속할지 물어봐야합니다.

# %%
def add(x,y):
  return x + y

def minus(x,y):
  return x - y

def coocm(x, y):
  return x*y

def devide(x, y):
  return x/y

def sqrt(x, y):
  return x ** y

while True:
  try:

    anum = int(input("정수를 입력해주세요"))

  except ValueError:
          print("정수가 아니에요")
          anum = int(input("정수를 입력해주세요"))

  else:
    try:
      bnum = int(input("두번째 정수를 입력해주세요"))
    except ValueError:
          print("정수가 아니에요")
          bnum = int(input("정수를 입력해주세요"))

    else: ccc = input("연산자[+ ,- ,/ ,* ,** ]입력 :")

    if ccc == "+":
            print(add(anum,bnum))

    elif ccc == "-":
            print(minus(anum,bnum))

    elif ccc == "/":
            print(devide(anum,bnum))

    elif ccc == "*":
            print(coocm(anum,bnum))

    elif ccc == "**":
            print(sqrt(anum,bnum))

    else:
        print("연산자를 잘못 입력했습니다.")


  finally:
    answer = input("계산을 계속하시나요? Y/N")
    try:
      if answer == Y:
       continue
    else:
        break
# Out:
# 정수를 입력해주세요123
# 두번째 정수를 입력해주세요123
# 연산자[+ ,- ,/ ,* ,** ]입력 :+
# 246
# 계산을 계속하시나요? Y/Nn
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_12190/2129524200.py in <cell line: 0>()
#      53   finally:
#      54     answer = input("계산을 계속하시나요? Y/N")
# ---> 55     if answer == Y:
#      56       continue
#      57     else:
#
# NameError: name 'Y' is not defined
